# %% [markdown]
# # Test digits
# Things are working and seem sane.

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch
import glob
from collections import defaultdict

from glia.util import load_checkpoint

# %%
# Pretty plots
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %config IPCompleter.greedy=True

import seaborn as sns

sns.set(font_scale=2)
sns.set_style("ticks")

plt.rcParams["axes.facecolor"] = "white"
plt.rcParams["figure.facecolor"] = "white"
plt.rcParams["font.size"] = "14"
plt.rcParams["legend.title_fontsize"] = "14"
# Uncomment for local development
# %load_ext nb_black
# %load_ext autoreload
# %autoreload 2

# %%
digits_test = torch.load(
    "/Users/qualia/Code/glia_playing_atari/data/digits_test.pytorch")

# %%
digits_test.keys()
# Out:
# dict_keys(['model_dict', 'vae_dict', 'glia', 'batch_size', 'test_batch_size', 'num_epochs', 'lr', 'vae_path', 'lr_vae', 'use_gpu', 'device_num', 'vae_loss', 'train_loss', 'test_loss', 'test_correct', 'correct', 'seed_value'])

# %%
plt.plot(digits_test["train_loss"], color="black")
plt.xlabel("Epoch")
plt.ylabel("Train error")
sns.despine()

# %%
plt.plot(digits_test["test_loss"], color="black")
plt.xlabel("Epoch")
plt.ylabel("Test error")
sns.despine()

# %%
plt.plot(digits_test["test_correct"], color="black")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
sns.despine()
